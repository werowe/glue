# %%
from datetime import date,timedelta
import uuid

import random
import simplejson as json


def getToday():
    return date.today().isoformat()

def generateOrderDict(record):
    
    j = {}
    
    columns=record.getColumns()
    values=record.getValues()
    
    
    for i in range(len(columns)):
        j[columns[i]] = values[i]
        
    
    return (j)

# %%
class Customer:
    
    columns = ['customernumber',
     'customername',           
    'phonenumber',
    'postalcode',
    'locale',
    'datecreated',
    'email']
    
    salesOrders = []

    
    def __init__(self):
        
        self.customernumber = str(random.randint(100,999))
        self.customername = randomString(20)
        self.phonenumber = random.randint(1000000,9000000)
        self.postalcode = randomString(4)
        self.locale = ''
        self.datecreated = getToday()
        self.email = randomString(4) + '@' + randomString(4) + ".com"
        
      
        
    def getColumns(self):
        return self.columns
    
    def getValues(self):
               
        return [self.customernumber,
            self.customername,
            self.phonenumber,
            self.postalcode,
            self.locale,
            self.datecreated,
            self.email]

    def getSalesOrders(self):
        return self.salesOrders
     
class SalesOrder:
    
    products = ['AA111', 'BB111', 'CC222', 'EE333', 'FF4444']

    columns =  ['customernumber',
        'ordernumber' ,
        'comments' ,
        'orderdate' ,
        'ordertype' ,
        'shipdate'  ,
        'discount'  ,
        'quantity'  ,
        'productnumber']

    def __init__(self, customerNumber):

        self.customernumber = customerNumber
        self.ordernumber = str(random.randint(100,999))
        self.comments = randomString(10)
        self.orderdate =  getToday()
        self.ordertype = "sale"
        self.shipdate  =  (date.today() + timedelta(days=random.randint(3,14))).isoformat()
        self.discount  = random.random()
        self.quantity  = random.randint(1,100)
        self.productnumber = self.products[random.randint(0,4)]  
        
    def getColumns(self):
        return self.columns    
        
        
    def getValues(self):
        return  [ self.customernumber,
        self.ordernumber ,
        self.comments ,
        self.orderdate ,
        self.ordertype ,
        self.shipdate  ,
        self.discount  ,
        self.quantity  ,
        self.productnumber ]

# %%
def randomString(length):
    
    char=""
    for i in range(length):
        char = char + chr(random.randint(97,122))
    return char

# %%
def commaCheck(field):
    
    if isinstance(field,int):
        return  str(field)  
    if isinstance(field,float):
        return  str(field) 
    else:
        return field

# %%
def generateCustomers(c,o,format):
    for i in range(5):        
        customer = Customer()
       
        columns = ','.join([col for col in customer.getColumns()])
        values = ','.join(["'" + commaCheck(value) + "'" for value in customer.getValues()])

        j=""
      
        if format=="SQL":
            sql="insert into customers ({}) values ({});".format(columns,values)
            print(sql)
        else:
            j=generateJSON(customer)
            j=json.dumps(j)
      
        c.write(j)
        generateOrders(customer,o,format)

# %%
def generateOrders(customer,o,format):
    
    for i in range(random.randint(1,4)):
    
        order=SalesOrder(customer.customernumber)
         
        columns = ','.join([col for col in order.getColumns()])
     
        values = ','.join(["'" + commaCheck(value) + "'" for value in order.getValues()])

        j=generateOrderDict(order)
        customer.salesOrders.append(j)
        
        if format=="SQL":
            sql="insert into orders ({}) values ({});".format(columns, values)
            print(sql)
            o.write(sql)
        else:
            print(j)
            o.write(json.dumps(sql))

# %%
def main():
    
    c = open("customers.json", "w")
    o = open("orders.json", "w")
    
    generateCustomers(c,o, "SQL")
    
    c.close()
    o.close()
   

if __name__ == "__main__":
    main()
# Out:
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('568','tlwotasvgeuzylfckhwz','6960682','lkoo','','2020-09-27','xdam@hjzy.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('568','206','vwgyzgywai','2020-09-27','sale','2020-10-06','0.029680645656964266','76','FF4444');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('568','577','uufxusuiqo','2020-09-27','sale','2020-10-01','0.2244447507751104','44','BB111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('568','281','mknfmkmmep','2020-09-27','sale','2020-10-06','0.03483009516842017','18','FF4444');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('568','545','owzxauutdw','2020-09-27','sale','2020-10-02','0.903687807534156','63','EE333');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('684','hwjkmomcxclttfrprekb','6066689','spjp','','2020-09-27','zcdm@jrhr.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('684','760','szohatnzev','2020-09-27','sale','2020-10-07','0.8988326363860707','4','AA111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('684','803','xofpgoqeus','2020-09-27','sale','2020-10-04','0.19108411492833466','78','FF4444');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('684','576','kgoznyhqdc','2020-09-27','sale','2020-10-04','0.08903489768729822','17','BB111');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('927','uudxmgknewwyelcrnpnv','8864647','zaei','','2020-09-27','bild@ouoy.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('927','561','cxdwtdaocc','2020-09-27','sale','2020-10-08','0.3189666702824382','18','AA111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('927','267','qfjfwcmbxq','2020-09-27','sale','2020-10-05','0.07075675997223829','63','BB111');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('927','445','vjpvgeljvm','2020-09-27','sale','2020-10-03','0.7011478779554541','55','CC222');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('972','efzhdmowkthjdsowmaxd','4701253','prte','','2020-09-27','vylx@fybz.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('972','919','bvoxpmnljo','2020-09-27','sale','2020-10-07','0.07081445038301548','41','AA111');
# insert into customers (customernumber,customername,phonenumber,postalcode,locale,datecreated,email) values ('466','ojiruhhhoooyadzgweqr','8394165','mshz','','2020-09-27','iicc@tcpw.com');
# insert into orders (customernumber,ordernumber,comments,orderdate,ordertype,shipdate,discount,quantity,productnumber) values ('466','934','bvuqjaqdkx','2020-09-27','sale','2020-10-05','0.5516502790684329','98','AA111');

# %% [markdown]
# ```sql
# CREATE TABLE customers
#   (
#      customernumber     varchar(100) PRIMARY KEY,
#     customername varchar(50),
#     phonenumber varchar(50),
#     postalcode varchar(50),
#     locale varchar(10),
#     datecreated date,
#     email varchar(50)
#   );
#  ```

# %% [markdown]
#
# ```sql
# CREATE TABLE orders
#   (
#      customernumber     varchar(100) PRIMARY KEY,
#     ordernumber varchar(100),
#     comments varchar(200),
#     orderdate date,
#     ordertype varchar(10),
#     shipdate date,
# discount number,
# quantity int,
#     productnumber varchar(50)
# )
# ```
